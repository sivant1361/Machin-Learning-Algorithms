# %%
import matplotlib.pyplot as p
import seaborn as s
from sklearn.cluster import KMeans as k
import numpy as n
# %matplotlib inline

# %%
x=n.random.rand(50,2)
#y=n.random.rand(50)*80
for i in range(25,50):
    x[i][:]=x[i][:]*-1
x
# Out:
# array([[ 1.94123203e-01,  6.65070337e-01],
#        [ 8.87443339e-01,  3.94385966e-01],
#        [ 5.44650853e-01,  2.33845739e-01],
#        [ 1.56020726e-01,  1.41296092e-01],
#        [ 8.80370204e-01,  4.44697350e-01],
#        [ 4.65671708e-01,  8.83209668e-01],
#        [ 2.88064576e-01,  6.24696929e-02],
#        [ 7.45308710e-01,  6.83125810e-01],
#        [ 5.06771311e-01,  7.85718750e-01],
#        [ 7.61836638e-01,  2.74339937e-01],
#        [ 8.59736019e-01,  1.73675769e-01],
#        [ 1.40704525e-01,  4.30008018e-01],
#        [ 8.11288813e-01,  8.02178093e-01],
#        [ 6.98063315e-01,  2.97428746e-01],
#        [ 6.23303283e-01,  1.06996266e-01],
#        [ 6.66930669e-01,  7.29596066e-01],
#        [ 4.93447432e-01,  8.89571088e-01],
#        [ 1.38389707e-01,  8.14846618e-01],
#        [ 1.90582234e-01,  1.64132240e-01],
#        [ 2.07405518e-01,  5.91729761e-04],
#        [ 9.18476168e-01,  8.75683303e-01],
#        [ 1.21800433e-01,  9.36385637e-01],
#        [ 9.83589801e-01,  2.82866937e-01],
#        [ 3.36626100e-01,  8.39625789e-01],
#        [ 5.90307647e-01,  6.11050346e-01],
#        [-7.50730182e-01, -8.55938369e-01],
#        [-9.77069403e-01, -3.11227465e-01],
#        [-9.14420487e-01, -1.39954232e-02],
#        [-7.51516472e-01, -1.89921989e-01],
#        [-7.97366002e-01, -5.14582206e-02],
#        [-6.56949170e-01, -1.50809070e-01],
#        [-2.06307450e-01, -6.32098728e-02],
#        [-8.58440548e-01, -2.85050254e-02],
#        [-5.43256871e-01, -9.93185183e-01],
#        [-1.44946757e-01, -9.20084154e-02],
#        [-8.62513265e-01, -1.69628782e-01],
#        [-9.34711300e-01, -3.45737576e-01],
#        [-9.40992561e-01, -2.63898415e-01],
#        [-9.86708034e-01, -8.28339054e-01],
#        [-8.77264276e-01, -7.27623632e-01],
#        [-3.90214930e-01, -7.52890232e-02],
#        [-4.51391275e-01, -2.48351987e-01],
#        [-6.70688261e-01, -4.42511686e-01],
#        [-1.75348660e-01, -4.00431608e-01],
#        [-2.92272610e-01, -5.98069118e-01],
#        [-9.18378711e-01, -7.70626662e-01],
#        [-6.68143460e-01, -6.45540290e-01],
#        [-6.91341065e-01, -4.53987379e-01],
#        [-1.26871552e-01, -8.27513045e-02],
#        [-8.69393933e-01, -5.16811023e-01]])

# %%
s.swarmplot(x[:,0],x[:,1],s=13)

# %%
km=k(n_clusters=2)

# %%
km.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centres=km.cluster_centers_
centres
# Out:
# array([[-0.65828949, -0.37279426],
#        [ 0.52843652,  0.50091184]])

# %%
p.scatter(x[:,0],x[:,1],cmap="magma")
p.scatter(centres[:,0],centres[:,1],c="green",s=150)
